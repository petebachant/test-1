# %%
import pandas

pandas.__file__
# Out:
# '/Users/pete/calkit/test-1/.calkit/envs/py/.venv/lib/python3.12/site-packages/pandas/__init__.py'

# %%
import pandas as pd

ax = pd.DataFrame(range(15)).plot()

ax.get_figure().savefig("figures/test.png")
