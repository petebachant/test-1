# %%
import pandas

pandas.__file__
# Out:
# '/Users/pete/calkit/test-1/.calkit/envs/py/.venv/lib/python3.12/site-packages/pandas/__init__.py'

# %%
import pandas as pd

pd.DataFrame(range(10)).plot()
# Out:
# <Axes: >
