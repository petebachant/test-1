# %%
import polars

print("sup")

polars.__file__
# Out:
# sup
# '/Users/pete/mambaforge/envs/test-1.conda-polars/lib/python3.14/site-packages/polars/__init__.py'

# %%
df = polars.DataFrame({"a": [1, 2, 3], "b": [4, 5, 6]})

df.write_avro("data.avro")
df.write_parquet("data.parquet")
