# %%
import pandas as pd

print("hiii dude")

pd.__version__, pd.__file__
# Out:
# hiii dude
# ('3.0.1',
#  '/Users/pete/calkit/test-1/.calkit/envs/py/.venv/lib/python3.12/site-packages/pandas/__init__.py')

# %%
import json
import os

os.makedirs("../results", exist_ok=True)

with open("../results/sup.json", "w") as f:
    json.dump({"a": 1}, f)
